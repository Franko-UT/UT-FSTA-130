# %% [markdown]
# ---
#
# ### **Data Summarization:**
#
# 1. **What is the best measure of central tendency for skewed data?**
#    - a) Mean
#    - b) Median
#    - c) Mode
#    - d) Standard Deviation
#
# 2. **Which of the following is not a measure of spread?**
#    - a) Range
#    - b) Variance
#    - c) Mode
#    - d) Interquartile Range
#
# 3. **Which visualization is most appropriate for comparing the distribution of two numeric variables?**
#    - a) Histogram
#    - b) Scatter plot
#    - c) Bar chart
#    - d) Pie chart
#
# 4. **What does a boxplot visually summarize?**
#    - a) Mean and mode
#    - b) Minimum, first quartile, median, third quartile, and maximum
#    - c) Mean and range
#    - d) Standard deviation and variance
#
# 5. **What is the formula for variance in Python using `numpy`?**
#    - a) `np.std(data)`
#    - b) `np.mean(data)`
#    - c) `np.var(data)`
#    - d) `np.median(data)`
#
# 6. **What Python function would you use to calculate the median of a dataset?**
#    - a) `np.mean()`
#    - b) `np.var()`
#    - c) `np.median()`
#    - d) `np.percentile()`
#
# 7. **Which of the following visualizations would you use to compare categorical data?**
#    - a) Scatter plot
#    - b) Bar chart
#    - c) Histogram
#    - d) Line graph
#
# 8. **A negatively skewed dataset will have the:**
#    - a) Mean < Median
#    - b) Mean = Median
#    - c) Mean > Median
#    - d) None of the above
#
# 9. **Which method returns summary statistics for a Pandas DataFrame?**
#    - a) `df.mean()`
#    - b) `df.describe()`
#    - c) `df.summary()`
#    - d) `df.stats()`
#
# 10. **Which Python library is primarily used for data manipulation and analysis?**
#     - a) Numpy
#     - b) Pandas
#     - c) Matplotlib
#     - d) Seaborn
#
# ---
#
# ### **Coding:**
#
# 11. **How do you import the Pandas library in Python?**
#     - a) `import pandas as pd`
#     - b) `import pandas as p`
#     - c) `import numpy as pd`
#     - d) `import pd as pandas`
#
# 12. **Which function calculates the standard deviation in Pandas?**
#     - a) `pd.std()`
#     - b) `df.var()`
#     - c) `df.std()`
#     - d) `df.mean()`
#
# 13. **What command will display the first 5 rows of a DataFrame `df`?**
#     - a) `df.show()`
#     - b) `df.head(5)`
#     - c) `df.head()`
#     - d) `df.sample(5)`
#
# 14. **Which of the following is a correct way to calculate the sum of a column `col` in a Pandas DataFrame `df`?**
#     - a) `df['col'].mean()`
#     - b) `df['col'].sum()`
#     - c) `df['col'].mode()`
#     - d) `df['col'].max()`
#
# 15. **Which package is used to create plots in Python?**
#     - a) Seaborn
#     - b) Matplotlib
#     - c) Pandas
#     - d) Scikit-learn
#
# 16. **What is the correct syntax to create a histogram using `matplotlib` in Python?**
#     - a) `plt.hist(data)`
#     - b) `plt.plot(data)`
#     - c) `plt.scatter(data)`
#     - d) `plt.bar(data)`
#
# 17. **Which function would you use to calculate correlation between two variables in a DataFrame?**
#     - a) `df.corr()`
#     - b) `df.cov()`
#     - c) `df.sum()`
#     - d) `df.groupby()`
#
# 18. **How do you remove missing values from a Pandas DataFrame?**
#     - a) `df.dropna()`
#     - b) `df.remove()`
#     - c) `df.drop()`
#     - d) `df.clear()`
#
# 19. **How do you select only the numeric columns of a DataFrame `df` in Python?**
#     - a) `df.dtypes == 'int'`
#     - b) `df.select_dtypes(include=[np.number])`
#     - c) `df.select('number')`
#     - d) `df.isnumeric()`
#
# 20. **Which of the following is a method to sort a DataFrame by a column?**
#     - a) `df.sort_values(by='col')`
#     - b) `df.order(by='col')`
#     - c) `df.groupby('col')`
#     - d) `df.arrange(by='col')`
#
# ---
#
# ### **Bootstrapping:**
#
# 21. **What is the primary purpose of bootstrapping in statistics?**
#     - a) To reduce the size of data
#     - b) To estimate confidence intervals
#     - c) To calculate p-values
#     - d) To find the median of the data
#
# 22. **Which Python library is commonly used for bootstrapping methods?**
#     - a) `SciPy`
#     - b) `Matplotlib`
#     - c) `Statsmodels`
#     - d) `Seaborn`
#
# 23. **How is bootstrapping performed?**
#     - a) By resampling the original dataset with replacement
#     - b) By calculating the mean of the dataset
#     - c) By randomly splitting the dataset in half
#     - d) By removing outliers
#
# 24. **Bootstrapping helps to estimate which of the following?**
#     - a) Population parameters
#     - b) Mean square error
#     - c) Distribution of a statistic
#     - d) All of the above
#
# 25. **How many times is the dataset typically resampled in bootstrapping?**
#     - a) 10
#     - b) 100
#     - c) 1000+
#     - d) Unlimited
#
# ---
#
# ### **Hypothesis Testing:**
#
# 26. **In a one-sample hypothesis test, the null hypothesis usually states that:**
#     - a) The sample mean is equal to the population mean
#     - b) The sample mean is less than the population mean
#     - c) The sample mean is greater than the population mean
#     - d) The sample mean is unequal to the population mean
#
# 27. **Which of the following is a commonly used significance level in hypothesis testing?**
#     - a) 0.01
#     - b) 0.05
#     - c) 0.10
#     - d) 0.50
#
# 28. **In Python, which function can be used to perform a one-sample t-test?**
#     - a) `scipy.stats.ttest_1samp()`
#     - b) `numpy.stats.ttest_1samp()`
#     - c) `pandas.ttest_1samp()`
#     - d) `matplotlib.ttest_1samp()`
#
# 29. **Which of the following best describes a Type I error in hypothesis testing?**
#     - a) Rejecting a true null hypothesis
#     - b) Failing to reject a true null hypothesis
#     - c) Rejecting a false null hypothesis
#     - d) Failing to reject a false null hypothesis
#
# 30. **What is the main advantage of using bootstrapping for hypothesis testing?**
#     - a) It is faster than traditional methods
#     - b) It makes fewer assumptions about the population distribution
#     - c) It always provides exact p-values
#     - d) It reduces the sample size required
#
# ---
#
# ### **Data Summarization:**
#
# 31. **Which measure is most sensitive to outliers?**
#     - a) Median
#     - b) Mode
#     - c) Mean
#     - d) Interquartile Range
#
# 32. **What does the standard deviation measure?**
#     - a) Central tendency
#     - b) The spread of data
#     - c) Skewness of data
#     - d) Data symmetry
#
# 33. **In Python, which function will calculate the variance of a dataset using `Pandas`?**
#     - a) `df.var()`
#     - b) `df.mean()`
#     - c) `df.median()`
#     - d) `df.stdev()`
#
# 34. **Which of the following correctly computes the interquartile range (IQR)?**
#     - a) `q3 - q2`
#     - b) `q1 - q3`
#     - c) `q3 - q1`
#     - d) `q1 + q3`
#
# 35. **Which plot is best for showing the frequency distribution of a dataset?**
#     - a) Line plot
#     - b) Histogram
#     - c) Boxplot
#     - d) Scatter plot
#
# 36. **What does a right-skewed distribution look like?**
#     - a) Tail on the right side
#     - b) Tail on the left side
#     - c) Symmetrical with no tail
#     - d) No skew
#
# 37. **In Python, how do you calculate the 25th percentile of a dataset using `numpy`?**
#     - a) `np.percentile(data, 50)`
#     - b) `np.percentile(data, 25)`
#     - c) `np.median(data)`
#     - d) `np.quantile(data, 25)`
#
# 38. **Which of the following is a valid method to detect outliers?**
#     - a) Mean calculation
#     - b) Median absolute deviation
#     - c) Standard deviation
#     - d) Correlation matrix
#
# 39. **What is the purpose of scaling data?**
#     - a) To decrease data size
#     - b) To standardize variable ranges
#     - c) To handle missing data
#     - d) To perform dimensionality reduction
#
# 40. **Which type of plot would be best to visualize the relationship between two continuous variables?**
#     - a) Histogram
#     - b) Boxplot
#     - c) Scatter plot
#     - d) Bar chart
#
# ---
#
# ### **Coding:**
#
# 41. **How do you load a CSV file into a DataFrame using `Pandas`?**
#     - a) `pd.load_csv('file.csv')`
#     - b) `pd.read('file.csv')`
#     - c) `pd.read_csv('file.csv')`
#     - d) `pd.load('file.csv')`
#
# 42. **Which command provides the number of rows and columns of a DataFrame `df`?**
#     - a) `df.size()`
#     - b) `df.shape`
#     - c) `df.length()`
#     - d) `df.describe()`
#
# 43. **Which method would you use to change the column names of a DataFrame in Python?**
#     - a) `df.rename()`
#     - b) `df.columns()`
#     - c) `df.set_names()`
#     - d) `df.rename_axis()`
#
# 44. **How do you remove duplicates from a DataFrame?**
#     - a) `df.drop_duplicates()`
#     - b) `df.remove_duplicates()`
#     - c) `df.clean_duplicates()`
#     - d) `df.filter_duplicates()`
#
# 45. **What does `df.drop('col', axis=1)` do?**
#     - a) Drops missing values in `col`
#     - b) Deletes the column `col` from the DataFrame
#     - c) Deletes the row containing `col`
#     - d) Removes duplicates in `col`
#
# 46. **How do you concatenate two DataFrames `df1` and `df2` vertically?**
#     - a) `pd.concat([df1, df2], axis=1)`
#     - b) `pd.merge([df1, df2])`
#     - c) `pd.concat([df1, df2], axis=0)`
#     - d) `pd.concat([df1, df2])`
#
# 47. **What is the purpose of the `groupby` function in Pandas?**
#     - a) To apply functions on subsets of data
#     - b) To calculate correlation
#     - c) To merge two DataFrames
#     - d) To perform element-wise operations
#
# 48. **Which of the following methods will sort a DataFrame by a column in descending order?**
#     - a) `df.sort_by()`
#     - b) `df.sort_values(ascending=False)`
#     - c) `df.sort_index()`
#     - d) `df.sort_values(ascending=True)`
#
# 49. **What does `df.mean(axis=1)` compute?**
#     - a) Mean across rows
#     - b) Mean across columns
#     - c) Median across rows
#     - d) Mode across rows
#
# 50. **What is the output of `df.info()`?**
#     - a) Basic statistical summary of the DataFrame
#     - b) Data types, non-null counts, and memory usage
#     - c) Shape of the DataFrame
#     - d) Correlation matrix of the DataFrame
#
# ---
#
# ### **Bootstrapping:**
#
# 51. **How do you implement bootstrapping in Python?**
#     - a) Resample the dataset without replacement
#     - b) Randomly sample the dataset with replacement
#     - c) Calculate the median multiple times
#     - d) Split the dataset into equal halves
#
# 52. **In bootstrapping, why do we sample with replacement?**
#     - a) To introduce bias into the sample
#     - b) To simulate repeated sampling from the population
#     - c) To reduce sample size
#     - d) To remove missing data
#
# 53. **What is the main benefit of bootstrapping?**
#     - a) It can work with small samples
#     - b) It provides an exact p-value
#     - c) It assumes a normal distribution
#     - d) It requires fewer iterations
#
# 54. **Which Python package is useful for implementing bootstrapping?**
#     - a) `statsmodels`
#     - b) `matplotlib`
#     - c) `pandas`
#     - d) `seaborn`
#
# 55. **What statistic is commonly estimated using bootstrapping?**
#     - a) Median
#     - b) Mean
#     - c) Confidence interval
#     - d) p-value
#
# 56. **Which of the following is a valid reason to use bootstrapping?**
#     - a) The population is unknown or hard to measure
#     - b) The dataset is too large to handle
#     - c) The data contains no variation
#     - d) The sample is normally distributed
#
# 57. **Bootstrapping involves which type of resampling?**
#     - a) Random sampling with replacement
#     - b) Random sampling without replacement
#     - c) Splitting the data into equal parts
#     - d) Removing outliers
#
# 58. **How does bootstrapping help in hypothesis testing?**
#     - a) By generating confidence intervals
#     - b) By reducing the sample size
#     - c) By splitting the dataset into training and testing sets
#     - d) By avoiding normality assumptions
#
# 59. **What is the general goal of bootstrapping?**
#     - a) Estimate the sampling distribution of a statistic
#     - b) Increase the number of data points
#     - c) Eliminate outliers from the dataset
#     - d) Decrease computation time
#
# 60. **How many bootstrap samples should be generated for reliable estimates?**
#     - a) 10
#     - b) 100
#     - c) 1000+
#     - d) 1
#
# ---
